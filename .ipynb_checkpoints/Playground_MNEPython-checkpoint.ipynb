# %%
# imports 
import mne
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %matplotlib inline

# %%
# %gui qt

# %% [markdown]
# ### Load Data

# %%
fdir = 'Experiment/output_data/'
fname = 'sub-1_ses-sleepy.fif'
raw = mne.io.read_raw_fif(fdir+fname)

# Details über die Elektroden und den Aplifier
# Out:
# Opening raw data file Experiment/output_data/sub-1_ses-sleepy.fif...
# Isotrak not found
#     Range : 0 ... 14868 =      0.000 ...    29.736 secs
# Ready.
# C:\Users\gross\AppData\Local\Temp\ipykernel_18644\2976534055.py:3: RuntimeWarning: This filename (Experiment/output_data/sub-1_ses-sleepy.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fdir+fname)

# %%
#raw.plot(scalings=1e-1)
raw.plot_psd(0,30)

raw.plot(duration=3, n_channels=5, scalings=1e-1)
plt.show()
# Out:
# Effective window size : 4.096 (s)
# C:\Users\gross\AppData\Local\Temp\ipykernel_18644\4273267152.py:2: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(0,30)
# <MNELineFigure size 720x252 with 1 Axes>
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 #raw.plot(scalings=1e-1)
#       2 raw.plot_psd(0,30)
# ----> 3 raw.plot_psd_topo(0,30)
#       5 raw.plot(duration=3, n_channels=5, scalings=1e-1)
#       6 plt.show()
#
# File ~\anaconda3\lib\site-packages\mne\io\base.py:1591, in BaseRaw.plot_psd_topo(self, tmin, tmax, fmin, fmax, proj, n_fft, n_overlap, layout, color, fig_facecolor, axis_facecolor, dB, show, block, n_jobs, axes, verbose)
#    1585 @copy_function_doc_to_method_doc(plot_raw_psd_topo)
#    1586 def plot_psd_topo(self, tmin=0., tmax=None, fmin=0, fmax=100, proj=False,
#    1587                   n_fft=2048, n_overlap=0, layout=None, color='w',
#    1588                   fig_facecolor='k', axis_facecolor='k', dB=True,
#    1589                   show=True, block=False, n_jobs=1, axes=None,
#    1590                   verbose=None):
# -> 1591     return plot_raw_psd_topo(self, tmin=tmin, tmax=tmax, fmin=fmin,
#    1592                              fmax=fmax, proj=proj, n_fft=n_fft,
#    1593                              n_overlap=n_overlap, layout=layout,
#    1594                              color=color, fig_facecolor=fig_facecolor,
#    1595                              axis_facecolor=axis_facecolor, dB=dB,
#    1596                              show=show, block=block, n_jobs=n_jobs,
#    1597                              axes=axes, verbose=verbose)
#
# File <decorator-gen-184>:12, in plot_raw_psd_topo(raw, tmin, tmax, fmin, fmax, proj, n_fft, n_overlap, layout, color, fig_facecolor, axis_facecolor, dB, show, block, n_jobs, axes, verbose)
#
# File ~\anaconda3\lib\site-packages\mne\viz\raw.py:502, in plot_raw_psd_topo(raw, tmin, tmax, fmin, fmax, proj, n_fft, n_overlap, layout, color, fig_facecolor, axis_facecolor, dB, show, block, n_jobs, axes, verbose)
#     500 if layout is None:
#     501     from ..channels.layout import find_layout
# --> 502     layout = find_layout(raw.info)
#     504 psds, freqs = psd_welch(raw, tmin=tmin, tmax=tmax, fmin=fmin,
#     505                         fmax=fmax, proj=proj, n_fft=n_fft,
#     506                         n_overlap=n_overlap, n_jobs=n_jobs)
#     507 if dB:
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:426, in find_layout(info, ch_type, exclude)
#     423     if not isinstance(info, (dict, Info)):
#     424         raise RuntimeError('Cannot make EEG layout, no measurement info '
#     425                            'was passed to `find_layout`')
# --> 426     return make_eeg_layout(info, exclude=exclude)
#     427 elif has_csd_coils and ch_type in [None, 'csd']:
#     428     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:262, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     260     pick_kwargs.update(csd=True, eeg=False)
#     261 picks = pick_types(info, **pick_kwargs)
# --> 262 loc2d = _find_topomap_coords(info, picks)
#     263 names = [info['chs'][i]['ch_name'] for i in picks]
#     265 # Scale [x, y] to be in the range [-0.5, 0.5]
#     266 # Don't mess with the origin or aspect ratio
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:625, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     623     pos = np.asarray(pos)
#     624 else:
# --> 625     pos = _auto_topomap_coords(
#     626         info, picks, ignore_overlap=ignore_overlap, to_sphere=to_sphere,
#     627         sphere=sphere)
#     629 return pos
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:690, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     688 # Get EEG digitization points
#     689 if info['dig'] is None or len(info['dig']) == 0:
# --> 690     raise RuntimeError('No digitization points found.')
#     692 locs3d = np.array([point['r'] for point in info['dig']
#     693                    if point['kind'] == FIFF.FIFFV_POINT_EEG])
#     695 if len(locs3d) == 0:
#
# RuntimeError: No digitization points found.

# %%
# check if standard montag is set
if raw.info['dig'] is not None:
    print("Montage is set.")
else:
    print("Montage is not set.")
# Out:
# Montage is set.

# %%
# it is not so I use the standard one:
montage = mne.channels.make_standard_montage('standard_1020')
raw.info.set_montage(montage)
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F9, F7, F3, Fz, F4, F8, F10, T9, T7, C3, C4, T8, T10, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  dig: 27 items (3 Cardinal, 24 EEG)
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 500.0 Hz
# >

# %%
# Plot topomap for a specific time point (e.g., 100 ms)
time_point = 0.1  # In seconds
raw.plot_psd_topo(tmin=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 # Plot topomap for a specific time point (e.g., 100 ms)
#       2 time_point = 0.1  # In seconds
# ----> 3 raw.plot_psd_topo(times=[time_point])
#
# TypeError: plot_psd_topo() got an unexpected keyword argument 'times'

# %% [markdown]
# ## Load Data (example data)

# %%
sample_data_folder = mne.datasets.sample.data_path()

# %% [markdown]
# ## Preprocessing

# %%
# filtering 

# ICA component analysis

# %% [markdown]
# ## Analysis
# Das Ziel ist es den Energieverbrauch der beiden Datensätze zu vergleichen.
